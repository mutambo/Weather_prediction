# %%
# !pip install kaggle

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "C:\\Users\\Maxwel\\.kaggle"

# %%
import kaggle
# !kaggle datasets download ananthr1/weather-prediction -f seattle-weather.csv
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ananthr1/weather-prediction
# License(s): CC-BY-NC-SA-4.0
# ...
#   0%|          | 0.00/48.5k [00:00<?, ?B/s]
# 100%|##########| 48.5k/48.5k [00:00<00:00, 205kB/s]
# 100%|##########| 48.5k/48.5k [00:00<00:00, 204kB/s]

# %%
#to extract a zipfile----
#import zipfile
#zip_ref = zipfile.ZipFile('seattle-weather.csv')
#zip_ref.extract.all()
#zip_ref.close()

# %%
import pandas as pd
df = pd.read_csv('seattle-weather.csv')
df.head(20)
# Out:
#           date  precipitation  temp_max  temp_min  wind  weather
# 0   2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1   2012-01-02           10.9      10.6       2.8   4.5     rain
# 2   2012-01-03            0.8      11.7       7.2   2.3     rain
# 3   2012-01-04           20.3      12.2       5.6   4.7     rain
# 4   2012-01-05            1.3       8.9       2.8   6.1     rain
# 5   2012-01-06            2.5       4.4       2.2   2.2     rain
# 6   2012-01-07            0.0       7.2       2.8   2.3     rain
# 7   2012-01-08            0.0      10.0       2.8   2.0      sun
# 8   2012-01-09            4.3       9.4       5.0   3.4     rain
# 9   2012-01-10            1.0       6.1       0.6   3.4     rain
# 10  2012-01-11            0.0       6.1      -1.1   5.1      sun
# 11  2012-01-12            0.0       6.1      -1.7   1.9      sun
# 12  2012-01-13            0.0       5.0      -2.8   1.3      sun
# ...

# %%
df['date']=pd.to_datetime(df['date'],format="%Y-%m-%d")

# %%
# import sqlalchemy as sal
# engine = sal.create_engine('mssql//DESKTOP-MBNSD8O\SQLEXPRESS/weather?driver=ODBC+DRIVER+17+SQL+SERVER')
# conn=engine.connect()
import sqlalchemy as sal
engine = sal.create_engine('mssql://DESKTOP-MBNSD8O\\SQLEXPRESS/weather?driver=ODBC+Driver+17+for+SQL+Server')
conn = engine.connect()

# %%
df.to_sql('df_prediction' , con=conn, index = False, if_exists='append')
# Out:
# 65
